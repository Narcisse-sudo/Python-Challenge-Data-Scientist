# %% [markdown]
# ## Exemple de Preprocessing Simple (Encoding + Normalisation)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OrdinalEncoder, OneHotEncoder, PolynomialFeatures
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn import set_config
set_config(transform_output='pandas')

# %% [markdown]
# ## Data Diamonds

# %%
df = sns.load_dataset('diamonds')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# # Train test Split

# %%
train_set, test_set = train_test_split(df, test_size=0.2, random_state=0)

print("train set shape = ", train_set.shape)
print("test set shape = ", test_set.shape)
# Out:
# train set shape =  (43152, 10)
# test set shape =  (10788, 10)

# %% [markdown]
# # Encoding train set

# %%
df['cut'].unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
# ordre d'encodage des variables
cut_order = ['Fair','Good','Very Good','Premium', 'Ideal']
color_order = ['J','I','H','G','F','E','D']
clarity_order = ['I1', 'SI2', 'SI1','VS2', 'VS1', 'VVS2', 'VVS1', 'IF']

encoder = OrdinalEncoder(categories= [cut_order, color_order, clarity_order])
train_set[['cut','color','clarity']] = encoder.fit_transform(train_set[['cut','color', 'clarity']])

# %%
train_set.head()
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 26250   1.63  4.0    3.0      4.0   61.7   55.0  15697  7.56  7.60  4.68
# 31510   0.34  4.0    3.0      3.0   62.2   57.0    765  4.47  4.44  2.77
# 40698   0.40  4.0    5.0      5.0   61.7   56.0   1158  4.73  4.77  2.93
# 42634   0.58  3.0    2.0      2.0   62.1   55.0   1332  5.38  5.35  3.33
# 47714   0.63  2.0    6.0      2.0   62.8   57.0   1885  5.40  5.46  3.41

# %% [markdown]
# # Normalisation

# %%
normaliser = MinMaxScaler()
train_set = pd.DataFrame(normaliser.fit_transform(train_set), columns=df.columns)
train_set.head(3)
# Out:
#           carat  cut     color   clarity     depth     table     price  \
# 26250  0.297297  1.0  0.500000  0.571429  0.519444  0.333333  0.830990
# 31510  0.029106  1.0  0.500000  0.428571  0.533333  0.388889  0.023681
# 40698  0.041580  1.0  0.833333  0.714286  0.519444  0.361111  0.044929
#
#               x         y         z
# 26250  0.703911  0.129032  0.147170
# 31510  0.416201  0.075382  0.087107
# 40698  0.440410  0.080985  0.092138

# %%
test_set.head(3)
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 10176   1.10    Ideal     H     SI2   62.0   55.0   4733  6.61  6.65  4.11
# 16083   1.29    Ideal     H     SI1   62.6   56.0   6424  6.96  6.93  4.35
# 13420   1.20  Premium     I     SI1   61.1   58.0   5510  6.88  6.80  4.18

# %%
test_set_encoding = encoder.transform(df[['cut', 'color', 'clarity']])
test_set[ ['cut','color', 'clarity']] = pd.DataFrame(test_set_encoding)
test_set.head()
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 10176   1.10  4.0    2.0      1.0   62.0   55.0   4733  6.61  6.65  4.11
# 16083   1.29  4.0    2.0      2.0   62.6   56.0   6424  6.96  6.93  4.35
# 13420   1.20  3.0    1.0      2.0   61.1   58.0   5510  6.88  6.80  4.18
# 20407   1.50  4.0    4.0      2.0   60.9   56.0   8770  7.43  7.36  4.50
# 8909    0.90  2.0    4.0      3.0   61.7   57.0   4493  6.17  6.21  3.82

# %%
test_set = normaliser.transform(test_set)

# %% [markdown]
# # Pipeline Sklearn

# %%
from sklearn.pipeline import Pipeline, make_pipeline

# %%
df = sns.load_dataset('diamonds')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
train_set, test_set = train_test_split(df, test_size=0.2, random_state=0)

# %%
pipeline = make_pipeline(OrdinalEncoder(), MinMaxScaler())
# Ou Pipeline(steps = [ ( 'Encoder', OrdinalEncoder() ), ( 'Scaler', MinMaxScaler()) ] )

# %%
pipeline
# Out:
# Pipeline(steps=[('ordinalencoder', OrdinalEncoder()),
#                 ('minmaxscaler', MinMaxScaler())])

# %% [markdown]
# # Pipeline compose

# %%
from sklearn.compose import ColumnTransformer

# %%
categorical_cols = ['cut', 'color', 'clarity']
Encoder = ColumnTransformer(transformers=[("Encoder" , OrdinalEncoder(), categorical_cols )], remainder='passthrough')

# %%
pipeline = make_pipeline(Encoder, MinMaxScaler())
pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Encoder', OrdinalEncoder(),
#                                                   ['cut', 'color',
#                                                    'clarity'])])),
#                 ('minmaxscaler', MinMaxScaler())])

# %%
pipeline.fit_transform(train_set).head(3)
# Out:
#        Encoder__cut  Encoder__color  Encoder__clarity  remainder__carat  \
# 26250           0.5        0.500000          0.571429          0.297297
# 31510           0.5        0.500000          0.714286          0.029106
# 40698           0.5        0.166667          1.000000          0.041580
#
#        remainder__depth  remainder__table  remainder__price  remainder__x  \
# 26250          0.519444          0.333333          0.830990      0.703911
# 31510          0.533333          0.388889          0.023681      0.416201
# 40698          0.519444          0.361111          0.044929      0.440410
#
#        remainder__y  remainder__z
# 26250      0.129032      0.147170
# 31510      0.075382      0.087107
# 40698      0.080985      0.092138

# %%
pipeline.transform(test_set).head(3)
# Out:
#        Encoder__cut  Encoder__color  Encoder__clarity  remainder__carat  \
# 10176          0.50        0.666667          0.428571          0.187110
# 16083          0.50        0.666667          0.285714          0.226611
# 13420          0.75        0.833333          0.285714          0.207900
#
#        remainder__depth  remainder__table  remainder__price  remainder__x  \
# 10176          0.527778          0.333333          0.238214      0.615456
# 16083          0.544444          0.361111          0.329639      0.648045
# 13420          0.502778          0.416667          0.280223      0.640596
#
#        remainder__y  remainder__z
# 10176      0.112903      0.129245
# 16083      0.117657      0.136792
# 13420      0.115450      0.131447

# %% [markdown]
# # Pipeline Niveau 1

# %%
pipeline1 = Pipeline(steps=[
                             ('Normaliser', StandardScaler()), 
                             ('poly', PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)),
                             ('SelectFeature', SelectKBest(score_func = f_regression, k = 4)) 
                            ])
pipeline1
# Out:
# Pipeline(steps=[('Normaliser', StandardScaler()),
#                 ('poly',
#                  PolynomialFeatures(include_bias=False, interaction_only=True)),
#                 ('SelectFeature',
#                  SelectKBest(k=4,
#                              score_func=<function f_regression at 0x0000025ED7321EE0>))])

# %% [markdown]
# # Pipeline Niveau 2

# %%
from sklearn.compose import  make_column_selector as selector

# %%
Encoder2 = ColumnTransformer(transformers = [('Encoder',
                                               OneHotEncoder(sparse_output = False, drop='first', handle_unknown='ignore'),
                                               selector(dtype_include='category'))],
                            remainder = 'passthrough')

pipeline2 = Pipeline(steps = [
                                ('Encoder', Encoder2),
                                ('Poly', PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)),
                                ('Normaliser', MinMaxScaler()) ] )
pipeline2
# Out:
# Pipeline(steps=[('Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000025ED73CA150>)])),
#                 ('Poly', PolynomialFeatures(include_bias=False)),
#                 ('Normaliser', MinMaxScaler())])

# %% [markdown]
# # Pipeline Niveau 3

# %%
# Pipeline pour selectionné meilleurs variable categorielle après encodage
pipeline_cat = Pipeline(steps= [
    ('OneHot', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore')),
    ('SelectBest', SelectKBest(score_func=f_regression, k=1))
])

pipeline_cat
# Out:
# Pipeline(steps=[('OneHot',
#                  OneHotEncoder(drop='first', handle_unknown='ignore',
#                                sparse_output=False)),
#                 ('SelectBest',
#                  SelectKBest(k=1,
#                              score_func=<function f_regression at 0x0000025ED7321EE0>))])

# %%
Encoder3 = ColumnTransformer(transformers = [('cat_pipeline', 
                                              pipeline_cat, 
                                              selector(dtype_include='category') ) ],
                             remainder= 'passthrough' )

# %%
pipeline3 = Pipeline(steps=[
    ('Encoder', Encoder3),
    ('Poly', PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)),
    ('Normaliser', MinMaxScaler())
])

pipeline3
# Out:
# Pipeline(steps=[('Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat_pipeline',
#                                                   Pipeline(steps=[('OneHot',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False)),
#                                                                   ('SelectBest',
#                                                                    SelectKBest(k=1,
#                                                                                score_func=<function f_regression at 0x0000025ED7321EE0>))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000025ED7375010>)])),
#                 ('Poly', PolynomialFeatures(include_bias=False)),
#                 ('Normaliser', MinMaxScaler())])

# %% [markdown]
#  # Pipeline Niveau 4

# %%
columntransform = ColumnTransformer(remainder = 'passthrough',
                                    transformers = [
                                        ('categorical col transform',
                                        Pipeline(steps=[
                                            ('OneHot', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore') ),
                                            ('SelectBest', SelectKBest(score_func=f_regression, k=2))
                                        ]),
                                        selector(dtype_include='category')),
                                        ('Standar_Sacling', StandardScaler(), ['height', 'weight']),
                                        ('MinMax_scaling', MinMaxScaler(), ['age', 'floor']),
                                    ])

columntransform
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('categorical col transform',
#                                  Pipeline(steps=[('OneHot',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False)),
#                                                  ('SelectBest',
#                                                   SelectKBest(k=2,
#                                                               score_func=<function f_regression at 0x0000025ED7321EE0>))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000025ED73F1BE0>),
#                                 ('Standar_Sacling', StandardScaler(),
#                                  ['height', 'weight']),
#                                 ('MinMax_scaling', MinMaxScaler(),
#                                  ['age', 'floor'])])

# %%
pipeline4 = Pipeline(steps=[
                ('Encoder',columntransform),
                ('poly', PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)),
                ('normaliser', MinMaxScaler())
              ])

pipeline4
# Out:
# Pipeline(steps=[('Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('categorical col transform',
#                                                   Pipeline(steps=[('OneHot',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False)),
#                                                                   ('SelectBest',
#                                                                    SelectKBest(k=2,
#                                                                                score_func=<function f_regression at 0x0000025ED7321EE0>))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000025ED73F1BE0>),
#                                                  ('Standar_Sacling',
#                                                   StandardScaler(),
#                                                   ['height', 'weight']),
#                                                  ('MinMax_scaling',
#                                                   MinMaxScaler(),
#                                                   ['age', 'floor'])])),
#                 ('poly', PolynomialFeatures(include_bias=False)),
#                 ('normaliser', MinMaxScaler())])

# %%
# niveau quatre autre manière

column_transform = ColumnTransformer(transformers = [('select_cat', 
                                                      Pipeline( steps = [('OnehotEncoder', OneHotEncoder(sparse_output = False, drop='first', handle_unknown='ignore')),
                                                                         ('SelectFeature', SelectKBest(score_func=f_regression, k=5))]), 
                                                      selector(dtype_include='category')),
                                                     ('StandardScaler', StandardScaler(), ['height', 'weight']),
                                                     ('MinMaxScaler', MinMaxScaler(), ['age', 'floor'])
                                                     ],
                                    remainder = 'passthrough')

pipeline2 = Pipeline(steps=[('ColumnTransformer', column_transform),
                            ('Poly', PolynomialFeatures(include_bias=True, interaction_only=True)),
                            ('MinMax', MinMaxScaler())])
pipeline2
# Out:
# Pipeline(steps=[('ColumnTransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('select_cat',
#                                                   Pipeline(steps=[('OnehotEncoder',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False)),
#                                                                   ('SelectFeature',
#                                                                    SelectKBest(k=5,
#                                                                                score_func=<function f_regression at 0x0000025ED7321EE0>))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000025ED743B680>),
#                                                  ('StandardScaler',
#                                                   StandardScaler(),
#                                                   ['height', 'weight']),
#                                                  ('MinMaxScaler',
#                                                   MinMaxScaler(),
#                                                   ['age', 'floor'])])),
#                 ('Poly', PolynomialFeatures(interaction_only=True)),
#                 ('MinMax', MinMaxScaler())])
