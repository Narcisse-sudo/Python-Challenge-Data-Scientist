# %%
import pandas  as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ##### Analyse Multivariée
# Discret / Discret

# %%
pd.crosstab(df["sex"], df["smoker"], normalize=True)
# Out:
# smoker       Yes        No
# sex
# Male    0.245902  0.397541
# Female  0.135246  0.221311

# %%
# heatmap de seaborn
sns.heatmap(pd.crosstab(df['size'],df['day']),annot=True)
# Out:
# <Axes: xlabel='day', ylabel='size'>

# %% [markdown]
# Discret / Continue

# %%
df.groupby("sex")["tip"].describe()
# Out:
# C:\Users\dalko\AppData\Local\Temp\ipykernel_24692\199809758.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("sex")["tip"].describe()
#         count      mean       std  min  25%   50%   75%   max
# sex
# Male    157.0  3.089618  1.489102  1.0  2.0  3.00  3.76  10.0
# Female   87.0  2.833448  1.159495  1.0  2.0  2.75  3.50   6.5

# %%
df.groupby('sex')["tip"].mean().plot(kind='bar')
plt.show()
# Out:
# C:\Users\dalko\AppData\Local\Temp\ipykernel_24692\1455773486.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('sex')["tip"].mean().plot(kind='bar')

# %%
sns.catplot(data=df, x='sex', y='tip', kind='bar')
plt.show()

# %%
sns.catplot(data=df, x='sex', y='tip', kind='box')
plt.show()

# %%
sns.displot(data=df, x='tip', hue='sex')
plt.show()

# %% [markdown]
# Continue / Continue

# %%
plt.scatter(df['tip'], df['total_bill'])
plt.xlabel('tip')
plt.ylabel('total_bill')
plt.show()

# %%
sns.scatterplot(data=df, x='tip', y='total_bill')
plt.show()
